# %% [markdown]
# # Setup

# %%
pip install librosa noisereduce soundfile
# Out:
# Requirement already satisfied: librosa in /usr/local/lib/python3.10/dist-packages (0.10.2.post1)
# Collecting noisereduce
#   Downloading noisereduce-3.0.2-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: soundfile in /usr/local/lib/python3.10/dist-packages (0.12.1)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.10/dist-packages (from librosa) (3.0.1)
# Requirement already satisfied: numpy!=1.22.0,!=1.22.1,!=1.22.2,>=1.20.3 in /usr/local/lib/python3.10/dist-packages (from librosa) (1.26.4)
# Requirement already satisfied: scipy>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from librosa) (1.13.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from librosa) (1.3.2)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.10/dist-packages (from librosa) (1.4.2)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from librosa) (4.4.2)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.10/dist-packages (from librosa) (0.60.0)
# Requirement already satisfied: pooch>=1.1 in /usr/local/lib/python3.10/dist-packages (from librosa) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.10/dist-packages (from librosa) (0.4.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in /usr/local/lib/python3.10/dist-packages (from librosa) (4.12.2)
# Requirement already satisfied: lazy-loader>=0.1 in /usr/local/lib/python3.10/dist-packages (from librosa) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.10/dist-packages (from librosa) (1.0.8)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from noisereduce) (3.7.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from noisereduce) (4.66.4)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.10/dist-packages (from soundfile) (1.16.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0->soundfile) (2.22)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from lazy-loader>=0.1->librosa) (24.1)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.51.0->librosa) (0.43.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.1->librosa) (4.2.2)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.1->librosa) (2.31.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->librosa) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->noisereduce) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->noisereduce) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->noisereduce) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->noisereduce) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->noisereduce) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->noisereduce) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->noisereduce) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->noisereduce) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2024.7.4)
# Downloading noisereduce-3.0.2-py3-none-any.whl (22 kB)
# Installing collected packages: noisereduce
# Successfully installed noisereduce-3.0.2

# %%
pip install pydub
# Out:
# Collecting pydub
#   Downloading pydub-0.25.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Installing collected packages: pydub
# Successfully installed pydub-0.25.1

# %%
! pip install pesq
# Out:
# Collecting pesq
#   Downloading pesq-0.0.4.tar.gz (38 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: pesq
#   Building wheel for pesq (setup.py) ... done
#   Created wheel for pesq: filename=pesq-0.0.4-cp310-cp310-linux_x86_64.whl size=262971 sha256=5178deb6c5bb259bba1a5e0bb89d87e293df73c1c54907b36456a10688a351d5
#   Stored in directory: /root/.cache/pip/wheels/c5/4e/2c/251524370c0fdd659e99639a0fbd0ca5a782c3aafcd456b28d
# Successfully built pesq
# Installing collected packages: pesq
# Successfully installed pesq-0.0.4

# %% [markdown]
# # Get Data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
! cp drive/MyDrive/dataset.rar ./

# %%
! unrar x dataset.rar
# Out:
# UNRAR 6.11 beta 1 freeware      Copyright (c) 1993-2022 Alexander Roshal
#
#
# Extracting from dataset.rar
#
# Creating    dataset                                                   OK
# Creating    dataset/clean                                             OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    dataset/noisy                                             OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# All OK

# %%
from pydub import AudioSegment
import os

def convert_m4a_to_wav_and_delete(directory_path):
    # Iterate through all files in the directory
    for filename in os.listdir(directory_path):
        if filename.endswith(".m4a"):
            # Construct the full file path
            file_path = os.path.join(directory_path, filename)

            # Load the M4A file
            audio = AudioSegment.from_file(file_path, format="m4a")

            # Extract the base name (without extension) for the new WAV file
            base_name = os.path.splitext(filename)[0]

            # Create the new WAV file path
            wav_file_path = os.path.join(directory_path, f"{base_name}.wav")

            # Export the audio in WAV format
            audio.export(wav_file_path, format="wav")

            # Check if the WAV file was successfully created
            if os.path.exists(wav_file_path):
                # Delete the original M4A file
                os.remove(file_path)
                print(f"M4A file '{file_path}' deleted successfully after conversion.")
            else:
                print(f"WAV file '{wav_file_path}' could not be created. Skipping deletion of M4A file '{file_path}'.")

# Example usage
directory_path = 'dataset/noisy'
convert_m4a_to_wav_and_delete(directory_path)
print("Conversion and deletion process complete.")
# Out:
# M4A file 'dataset/noisy/2-96-vc.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-108.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-91-3o.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-20-gg.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-36-nh.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-28-eu.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/1-1.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-19-fa-sn.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-58-3t.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-12.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-34.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-20-s7.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-51pi.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-104-1h.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-79.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-87-nb.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-49-sm.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-80.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-52.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-106.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-25-bq.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-93-57.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-71-56.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-90-op.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-56.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/1-2.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-28-po.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-19-fa-66.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-87-6u.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-23-ap.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-94.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-93-ra.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-91-bd.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-96-up.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-40-pl.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-49-6t.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-84.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-33-ct.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-90-4m.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-49-9a.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-41.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-71-7o.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-9.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-33-qu.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-58-rd.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-15.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-17.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-51-5p.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-110.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-104-a9.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-2.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-104-do.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/1-6.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-20-17.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-66.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-74.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-5.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-7.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-29-ur.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-53.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-75-o0.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/0-0.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-50-b8.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-13-fa-In.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/1-3.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-3.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-18.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-60-kq.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-6.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-21.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-83-v2.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-16.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-14.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-39.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-50-e8.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-40-hf.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/1-5.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-35-us.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-68.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-35-e8.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-11.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-38.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-30-lk.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-87-8a.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-47.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-4.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-91-to.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-29-cb.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-31.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-75-8p.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-29-en.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-93-9i.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-36-uq.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-73.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-50-br.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-36-3k.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-57.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-65.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-1.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-28-ia.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-93-25.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-96-54.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-8.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/1-4.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-24.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-30-f8.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-23-bat.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-25-3f.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-60-gp.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-104-ob.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-93-1a.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-30-kd.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-59.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-23-l2.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-25-18.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-63.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-13-fa-qp.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-10.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-87-gq.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-87-q4.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-97.m4a' deleted successfully after conversion.
# M4A file 'dataset/noisy/2-83-c8.m4a' deleted successfully after conversion.
# Conversion and deletion process complete.

# %% [markdown]
# # Enhance

# %%
import os
import librosa
import noisereduce as nr
import soundfile as sf

def load_audio(file_path):
    audio, sr = librosa.load(file_path, sr=None)
    return audio, sr

def save_audio(file_path, audio, sr):
    sf.write(file_path, audio, sr)

def remove_background_music(audio, sr):
    harmonic, percussive = librosa.effects.hpss(audio)
    return percussive

def denoise_audio(audio, sr):
    reduced_noise = nr.reduce_noise(y=audio, sr=sr)
    return reduced_noise

def process_audio(input_path, output_path):
    audio, sr = load_audio(input_path)
    vocals = remove_background_music(audio, sr)
    enhanced_audio = denoise_audio(vocals, sr)
    save_audio(output_path, enhanced_audio, sr)

def process_directory(input_dir, output_dir):
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    for filename in os.listdir(input_dir):
        if filename.endswith('.wav'):
            input_path = os.path.join(input_dir, filename)
            output_path = os.path.join(output_dir, filename)
            process_audio(input_path, output_path)
            print(f"Processed {filename}")

# %%
input_directory = 'dataset/noisy'
output_directory = 'dataset/denoised'
process_directory(input_directory, output_directory)
# Out:
# Processed 2-93-ra.wav
# Processed 2-110.wav
# Processed 2-35-e8.wav
# Processed 2-13-fa-In.wav
# Processed 2-28-ia.wav
# Processed 2-71-56.wav
# Processed 2-38.wav
# Processed 1-2.wav
# Processed 2-90-4m.wav
# Processed 2-59.wav
# Processed 2-16.wav
# Processed 2-31.wav
# Processed 2-49-sm.wav
# Processed 2-30-f8.wav
# Processed 2-87-q4.wav
# Processed 2-60-kq.wav
# Processed 2-91-3o.wav
# Processed 2-58-3t.wav
# Processed 2-106.wav
# Processed 2-28-eu.wav
# Processed 2-84.wav
# Processed 2-87-8a.wav
# Processed 2-29-ur.wav
# Processed 2-23-l2.wav
# Processed 2-40-pl.wav
# Processed 2-87-nb.wav
# Processed 2-33-qu.wav
# Processed 2-104-do.wav
# Processed 2-60-gp.wav
# Processed 2-51pi.wav
# Processed 2-11.wav
# Processed 2-80.wav
# Processed 0-0.wav
# Processed 2-8.wav
# Processed 2-21.wav
# Processed 1-6.wav
# Processed 2-30-lk.wav
# Processed 2-36-nh.wav
# Processed 2-71-7o.wav
# Processed 2-20-17.wav
# Processed 2-17.wav
# Processed 2-4.wav
# Processed 2-65.wav
# Processed 2-97.wav
# Processed 2-73.wav
# Processed 2-87-gq.wav
# Processed 2-93-1a.wav
# Processed 2-34.wav
# Processed 2-75-o0.wav
# Processed 2-50-br.wav
# Processed 2-91-bd.wav
# Processed 2-51-5p.wav
# Processed 2-20-gg.wav
# Processed 2-5.wav
# Processed 2-96-up.wav
# Processed 2-30-kd.wav
# Processed 2-50-b8.wav
# Processed 1-5.wav
# Processed 2-6.wav
# Processed 2-63.wav
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-a35dd49f461c> in <cell line: 3>()
#       1 input_directory = 'dataset/noisy'
#       2 output_directory = 'dataset/denoised'
# ----> 3 process_directory(input_directory, output_directory)
#
# <ipython-input-9-c2083ceaf0f6> in process_directory(input_dir, output_dir)
#      33             input_path = os.path.join(input_dir, filename)
#      34             output_path = os.path.join(output_dir, filename)
# ---> 35             process_audio(input_path, output_path)
#      36             print(f"Processed {filename}")
#
# <ipython-input-9-c2083ceaf0f6> in process_audio(input_path, output_path)
#      21 def process_audio(input_path, output_path):
#      22     audio, sr = load_audio(input_path)
# ---> 23     vocals = remove_background_music(audio, sr)
#      24     enhanced_audio = denoise_audio(vocals, sr)
#      25     save_audio(output_path, enhanced_audio, sr)
#
# <ipython-input-9-c2083ceaf0f6> in remove_background_music(audio, sr)
#      12
#      13 def remove_background_music(audio, sr):
# ---> 14     harmonic, percussive = librosa.effects.hpss(audio)
#      15     return percussive
#      16
#
# /usr/local/lib/python3.10/dist-packages/librosa/effects.py in hpss(y, kernel_size, power, mask, margin, n_fft, hop_length, win_length, window, center, pad_mode)
#     141
#     142     # Decompose into harmonic and percussives
# --> 143     stft_harm, stft_perc = decompose.hpss(
#     144         stft, kernel_size=kernel_size, power=power, mask=mask, margin=margin
#     145     )
#
# /usr/local/lib/python3.10/dist-packages/librosa/decompose.py in hpss(S, kernel_size, power, mask, margin)
#     391
#     392     perc = np.empty_like(S)
# --> 393     perc[:] = median_filter(S, size=perc_shape, mode="reflect")
#     394
#     395     split_zeros = margin_harm == 1 and margin_perc == 1
#
# /usr/local/lib/python3.10/dist-packages/scipy/ndimage/_filters.py in median_filter(input, size, footprint, output, mode, cval, origin, axes)
#    1592     >>> plt.show()
#    1593     """
# -> 1594     return _rank_filter(input, 0, size, footprint, output, mode, cval,
#    1595                         origin, 'median', axes=axes)
#    1596
#
# /usr/local/lib/python3.10/dist-packages/scipy/ndimage/_filters.py in _rank_filter(input, rank, size, footprint, output, mode, cval, origin, operation, axes)
#    1493                 "filters")
#    1494         mode = _ni_support._extend_mode_to_code(mode)
# -> 1495         _nd_image.rank_filter(input, rank, footprint, output, mode, cval,
#    1496                               origins)
#    1497         if temp_needed:
#
# KeyboardInterrupt:

# %% [markdown]
# # Calculate PESQ

# %%
import os
import numpy as np
from scipy.io import wavfile
from scipy.signal import resample
from pesq import pesq, PesqError

def read_and_resample(filepath, target_sample_rate):
    sr, audio = wavfile.read(filepath)
    if sr != target_sample_rate:
        # Calculate the number of samples after resampling
        num_samples = round(len(audio) * float(target_sample_rate) / sr)
        audio = resample(audio, num_samples)
    return audio

def calculate_pesq(clean_dir, denoised_dir, sample_rate=16000):
    pesq_scores = []

    clean_files = sorted(os.listdir(clean_dir))
    denoised_files = sorted(os.listdir(denoised_dir))

    for clean_file, denoised_file in zip(clean_files, denoised_files):
        clean_path = os.path.join(clean_dir, clean_file)
        denoised_path = os.path.join(denoised_dir, denoised_file)

        if os.path.isfile(clean_path) and os.path.isfile(denoised_path):
            try:
                # Read and resample the wav files
                clean_audio = read_and_resample(clean_path, sample_rate)
                denoised_audio = read_and_resample(denoised_path, sample_rate)

                # Calculate PESQ score
                score = pesq(sample_rate, clean_audio, denoised_audio, 'wb')
                pesq_scores.append(score)
                print(f'File: {clean_file}, PESQ: {score}')
            except PesqError as e:
                print(f"Error calculating PESQ for {clean_file} and {denoised_file}: {e}")
            except Exception as e:
                print(f"Error processing {clean_file} and {denoised_file}: {e}")

    return pesq_scores

if __name__ == "__main__":
    clean_dir = 'dataset/clean'
    denoised_dir = 'dataset/denoised'
    pesq_scores = calculate_pesq(clean_dir, denoised_dir)
    if pesq_scores:
        print(f'Average PESQ Score: {np.mean(pesq_scores)}')
    else:
        print('No PESQ scores calculated.')
# Out:
# File: 0-0-fa.wav, PESQ: 1.064836859703064
# File: 1-1-fa.wav, PESQ: 1.8641763925552368
# File: 1-2-fa.wav, PESQ: 1.019781470298767
# File: 1-3-fa.wav, PESQ: 1.1691797971725464
# File: 1-4-fa.wav, PESQ: 1.0388201475143433
# File: 1-5-fa.wav, PESQ: 1.145700454711914
# File: 1-6-fa.wav, PESQ: 1.0264787673950195
# File: 2-1-fa.wav, PESQ: 1.2230867147445679
# File: 2-10-fa.wav, PESQ: 1.2218201160430908
# File: 2-104-fa-1hjo92mg2e.wav, PESQ: 1.549081802368164
# File: 2-104-fa-a9o255k5afo.wav, PESQ: 1.0320544242858887
# File: 2-104-fa-do3d8akeuek.wav, PESQ: 1.0866756439208984
# File: 2-104-fa-obf721ivs0c.wav, PESQ: 1.0717822313308716
# File: 2-106-fa.wav, PESQ: 3.684998035430908
# File: 2-108-fa.wav, PESQ: 3.6968274116516113
# File: 2-11-fa.wav, PESQ: 1.0301624536514282
# File: 2-110-fa.wav, PESQ: 1.1114894151687622
# File: 2-12-fa.wav, PESQ: 1.025396704673767
# File: 2-13-fa-lnjrak25fbg.wav, PESQ: 1.1183013916015625
# File: 2-13-fa-qplgmvtr048.wav, PESQ: 1.127224326133728
# File: 2-14-fa.wav, PESQ: 1.146073818206787
# File: 2-15-fa.wav, PESQ: 1.0747904777526855
# File: 2-16-fa.wav, PESQ: 1.033399224281311
# File: 2-17-fa.wav, PESQ: 1.0233571529388428
# File: 2-18-fa.wav, PESQ: 1.0289931297302246
# File: 2-19-fa-66mpt4il69s.wav, PESQ: 1.6976170539855957
# File: 2-19-fa-snmm8fsnv8o.wav, PESQ: 1.0171324014663696
# File: 2-2-fa.wav, PESQ: 1.02406907081604
# File: 2-20-fa-17aglq7msv.wav, PESQ: 1.0236783027648926
# File: 2-20-fa-gg6b4lhj1hk.wav, PESQ: 1.0500239133834839
# File: 2-20-fa-s7taivstdak.wav, PESQ: 1.0898175239562988
# File: 2-21-fa.wav, PESQ: 1.0885398387908936
# File: 2-23-fa-apfi278r404.wav, PESQ: 1.771178960800171
# File: 2-23-fa-bat7gbh96qg.wav, PESQ: 1.102439284324646
# File: 2-23-fa-l20jkno16i8.wav, PESQ: 1.0554972887039185
# File: 2-24-fa.wav, PESQ: 1.7390120029449463
# File: 2-25-fa-18bi8cnb96s.wav, PESQ: 1.0400961637496948
# File: 2-25-fa-3fja2tutg1c.wav, PESQ: 1.0297613143920898
# File: 2-25-fa-bqldqtlqqh8.wav, PESQ: 1.173567533493042
# File: 2-28-fa-eur2j2mh93k.wav, PESQ: 1.019024133682251
# File: 2-28-fa-iahce8ngjvg.wav, PESQ: 1.0842347145080566
# File: 2-28-fa-po580n8cq3k.wav, PESQ: 1.0281119346618652
# File: 2-29-fa-cb9i8rmfqko.wav, PESQ: 1.0167386531829834
# File: 2-29-fa-enb7s6snqg8.wav, PESQ: 1.0355720520019531
# File: 2-29-fa-ur298pa8deo.wav, PESQ: 1.0413169860839844
# File: 2-3-fa.wav, PESQ: 3.5457890033721924
# File: 2-30-fa-f8ctq2cbsek.wav, PESQ: 1.033804178237915
# File: 2-30-fa-kdphmf7poec.wav, PESQ: 1.017093300819397
# File: 2-30-fa-lk1tuij5l6o.wav, PESQ: 1.0178438425064087
# File: 2-31-fa.wav, PESQ: 1.0191007852554321
# File: 2-33-fa-ctr5m3l6s58.wav, PESQ: 1.4085389375686646
# File: 2-33-fa-qutn4utfudo.wav, PESQ: 1.0709072351455688
# File: 2-34-fa.wav, PESQ: 3.021866798400879
# File: 2-35-fa-e8irmlicrj8.wav, PESQ: 1.044805884361267
# File: 2-35-fa-us9vuif5eho.wav, PESQ: 1.0401976108551025
# File: 2-36-fa-3kct5iec0hs.wav, PESQ: 1.1046719551086426
# File: 2-36-fa-nhkiic18b7.wav, PESQ: 1.077420711517334
# File: 2-36-fa-uqbln7kl4ko.wav, PESQ: 2.4811031818389893
# File: 2-38-fa.wav, PESQ: 1.2528663873672485
# File: 2-39-fa.wav, PESQ: 1.015981912612915
# Average PESQ Score: 1.3148984869321187

# %%
from IPython.display import Audio

noisy_file_path = 'dataset/noisy/0-0.wav'
denoised_file_path = 'dataset/denoised/0-0.wav'

# Display and play the audio file
Audio(noisy_file_path, autoplay=False)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio(denoised_file_path, autoplay=False)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
