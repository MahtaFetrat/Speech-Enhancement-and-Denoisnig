# %%
! wget https://datashare.is.ed.ac.uk/bitstream/handle/10283/2791/clean_trainset_28spk_wav.zip
! wget https://datashare.is.ed.ac.uk/bitstream/handle/10283/2791/noisy_trainset_28spk_wav.zip
! wget https://datashare.is.ed.ac.uk/bitstream/handle/10283/2791/clean_testset_wav.zip
! wget https://datashare.is.ed.ac.uk/bitstream/handle/10283/2791/noisy_testset_wav.zip
! wget https://datashare.is.ed.ac.uk/bitstream/handle/10283/2791/testset_txt.zip
! wget https://datashare.is.ed.ac.uk/bitstream/handle/10283/2791/trainset_28spk_txt.zip

# %%
! mkdir VCTK

# %%
! unzip clean_trainset_28spk_wav.zip -d VCTK
! unzip noisy_trainset_28spk_wav.zip -d VCTK
! unzip clean_testset_wav.zip -d VCTK
! unzip noisy_testset_wav.zip -d VCTK
! unzip testset_txt.zip -d VCTK
! unzip trainset_28spk_txt.zip -d VCTK
# Out:
# Archive:  clean_trainset_28spk_wav.zip
#    creating: VCTK/clean_trainset_28spk_wav/
#   inflating: VCTK/clean_trainset_28spk_wav/p226_001.wav
#   inflating: VCTK/clean_trainset_28spk_wav/p226_002.wav
#   inflating: VCTK/clean_trainset_28spk_wav/p226_003.wav
#   inflating: VCTK/clean_trainset_28spk_wav/p226_004.wav
#   inflating: VCTK/clean_trainset_28spk_wav/p226_005.wav
#   inflating: VCTK/clean_trainset_28spk_wav/p226_006.wav
#   inflating: VCTK/clean_trainset_28spk_wav/p226_007.wav
#   inflating: VCTK/clean_trainset_28spk_wav/p226_008.wav
#   inflating: VCTK/clean_trainset_28spk_wav/p226_009.wav
#   inflating: VCTK/clean_trainset_28spk_wav/p226_010.wav
#   inflating: VCTK/clean_trainset_28spk_wav/p226_011.wav
#   inflating: VCTK/clean_trainset_28spk_wav/p226_012.wav
#   inflating: VCTK/clean_trainset_28spk_wav/p226_013.wav
#   inflating: VCTK/clean_trainset_28spk_wav/p226_014.wav
#   inflating: VCTK/clean_trainset_28spk_wav/p226_015.wav
# ...

# %%
! mv VCTK/clean_trainset_28spk_wav VCTK/clean_trainset_28spk_wav_16k
! mv VCTK/noisy_trainset_28spk_wav VCTK/noisy_trainset_28spk_wav_16k
! mv VCTK/clean_testset_wav VCTK/clean_testset_wav_16k
! mv VCTK/noisy_testset_wav VCTK/noisy_testset_wav_16k

# %%
! git clone https://github.com/speechbrain/speechbrain/

# %%
! pip install pesq

# %%
! cd /media/external_2T/fetrat/speech-enhancement-original/speechbrain/recipes/Voicebank/enhance/MetricGAN && python train.py hparams/train.yaml --data_folder=/media/external_2T/fetrat/speech-enhancement-original/VCTK

# %% [markdown]
# ![image.png](attachment:image.png)
